# %%
class Accion:
    def __init__(self, nombre, ticker, pais, from_date, to_date):
        self.nombre = nombre
        self.ticker = ticker
        self.pais = pais
        self.from_date = from_date
        self.to_date = to_date
    def __str__(self):
        return "\nAccion: " + self.nombre + " - Ticker: " + self.ticker + " - Pais: " + self.pais + " - fecha desde:  " + self.from_date + " - fecha hasta: " + self.to_date
    
    def investPy(self):
        import investpy
        import pandas as pd
        df_accion=investpy.get_stock_historical_data(stock = self.ticker,
                                        country= self.pais,
                                        from_date= self.from_date,
                                        to_date= self.to_date)
        return df_accion
    
    def graficar(self, df_accion):
        
        import matplotlib.pyplot as plt

        x=df_accion['Date']
        y=df_accion['Close']
        plt.plot(x,y,marker="o")
        plt.xlabel("Fecha")
        plt.xticks(rotation=30, ha='right')
        plt.ylabel("Close", fontsize=15)
        plt.title("Compania: "+str(self.nombre)+ " - Pais: "+ str(self.pais), fontsize=25)

        plt.gcf().set_size_inches(15, 10)
        plt.show()

# %%
def main():
    import pandas as pd
    accion_nombre=str(input("Ingrese el nombre de la Compania: "))
    pais=str(input("Ingrese el pais: "))
    ticker=str(input("Ingrese el ticker: "))
    from_date=str(input("Ingrese la fecha de inicio: "))
    to_date=str(input("Ingrese la fecha de fin: "))
    accion=Accion(accion_nombre, ticker, pais, from_date, to_date)
    print(accion)
    
    df_accion=pd.DataFrame(accion.investPy())
    df_accion['Date'] = df_accion.index

    print(df_accion)
    accion.graficar(df_accion)

# %%
if __name__ == "__main__":
    main()
# Out:
# Ingrese el nombre de la Compania: Mercado Libre
# Ingrese el pais: argentina
# Ingrese el ticker: meli
# Ingrese la fecha de inicio: 01/10/2021
# Ingrese la fecha de fin: 30/10/2021
#
# Accion: Mercado Libre - Ticker: meli - Pais: argentina - fecha desde:  01/10/2021 - fecha hasta: 30/10/2021
#               Open    High     Low   Close  Volume Currency       Date
# Date
# 2021-10-01  5385.0  5421.5  5289.5  5385.0   19947      ARS 2021-10-01
# 2021-10-04  5331.0  5340.0  5083.0  5121.0   37100      ARS 2021-10-04
# 2021-10-05  5121.0  5130.0  5003.0  5046.0   23992      ARS 2021-10-05
# 2021-10-06  5000.0  5000.0  4871.0  4960.0   19302      ARS 2021-10-06
# 2021-10-07  5000.0  5071.0  4954.0  5015.0   46000      ARS 2021-10-07
# 2021-10-12  4797.0  4850.0  4669.0  4675.5   49928      ARS 2021-10-12
# 2021-10-13  4725.0  4920.0  4715.0  4920.0   40252      ARS 2021-10-13
# 2021-10-14  4940.0  4954.5  4871.0  4935.0   67522      ARS 2021-10-14
# 2021-10-15  4962.5  5099.5  4962.5  5091.0   35192      ARS 2021-10-15
# 2021-10-18  5100.0  5235.5  5050.0  5195.0   56876      ARS 2021-10-18
# 2021-10-19  5249.0  5279.5  5150.0  5200.0   50386      ARS 2021-10-19
# 2021-10-20  5200.0  5275.0  5170.0  5256.0   19228      ARS 2021-10-20
# 2021-10-21  5227.5  5270.0  5190.0  5221.0   25689      ARS 2021-10-21
# 2021-10-22  5190.0  5190.0  5007.0  5035.0   42303      ARS 2021-10-22
# 2021-10-25  5121.0  5234.0  5117.0  5123.0   25940      ARS 2021-10-25
# 2021-10-26  5130.0  5187.5  5057.5  5175.0   24053      ARS 2021-10-26
# 2021-10-27  5180.0  5180.0  5058.0  5069.0   24194      ARS 2021-10-27
# 2021-10-28  5065.0  5240.0  5050.0  5228.0   27878      ARS 2021-10-28
# 2021-10-29  5228.0  5228.0  5100.5  5186.0   18462      ARS 2021-10-29
