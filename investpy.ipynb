# %%
# Importamos librerias necesarias
import investpy
import pandas as pd

# Averiguamos en que mercados podemos usar Investpy
investpy.get_stock_countries()
# Out:
# ['argentina',
#  'brazil',
#  'canada',
#  'chile',
#  'colombia',
#  'costa rica',
#  'jamaica',
#  'mexico',
#  'peru',
#  'united states',
#  'venezuela',
#  'austria',
#  'belgium',
#  'bosnia',
#  'bulgaria',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hungary',
#  'iceland',
#  'ireland',
#  'italy',
#  'luxembourg',
#  'malta',
#  'montenegro',
#  'netherlands',
#  'norway',
#  'poland',
#  'portugal',
#  'romania',
#  'russia',
#  'serbia',
#  'slovakia',
#  'slovenia',
#  'spain',
#  'sweden',
#  'switzerland',
#  'turkey',
#  'ukraine',
#  'united kingdom',
#  'australia',
#  'bangladesh',
#  'china',
#  'hong kong',
#  'india',
#  'indonesia',
#  'japan',
#  'kazakhstan',
#  'malaysia',
#  'mongolia',
#  'new zealand',
#  'pakistan',
#  'philippines',
#  'singapore',
#  'south korea',
#  'sri lanka',
#  'taiwan',
#  'thailand',
#  'vietnam',
#  'bahrain',
#  'egypt',
#  'iraq',
#  'israel',
# ...

# %%
# Obtenemos un listado de las acciones del mercado que investigamos
investpy.stocks.get_stocks(country='argentina')
# Out:
#        country                      name                        full_name  \
# 0    argentina                   Tenaris                          Tenaris
# 1    argentina              PETROBRAS ON  Petroleo Brasileiro - Petrobras
# 2    argentina  Grupo Financiero Galicia       Grupo Financiero Galicia B
# 3    argentina         Ternium Argentina             Ternium Argentina SA
# 4    argentina             Pampa Energia                 Pampa Energia SA
# ..         ...                       ...                              ...
# 145  argentina             Arcos Dorados       Arcos Dorados Holdings Inc
# 146  argentina            Alibaba Cedear        Alibaba Group Holding Ltd
# 147  argentina                Gerdau DRC                        Gerdau SA
# 148  argentina                       BRF                           BRF SA
# 149  argentina         Ternium Argentina             Ternium Argentina SA
#
#              isin currency symbol
# 0    LU0156801721      ARS     TS
# ...

# %%
# Seleccionamos YPF
df_ypf=investpy.get_stock_historical_data(stock='ypfd',
                                        country='argentina',
                                        from_date='01/09/2021',
                                        to_date='01/10/2021')
df_ypf.head(5)
# Out:
#               Open   High     Low   Close  Volume Currency
# Date
# 2021-09-01  900.05  921.0  884.00  884.00  256452      ARS
# 2021-09-02  892.00  905.0  880.00  891.35  118742      ARS
# 2021-09-03  870.05  889.0  865.00  872.90   94057      ARS
# 2021-09-06  872.00  878.0  859.00  872.40   37650      ARS
# 2021-09-07  880.55  947.0  880.55  941.00  320402      ARS

# %%
df_ypf.to_csv('df_ypf_arg.csv', index = False)

# %%
# Seleccionamos Mercado libre
df_ml=investpy.get_stock_historical_data(stock='MELI',
                                        country='argentina',
                                        from_date='01/09/2021',
                                        to_date='01/10/2021')
df_ml.head(5)
# Out:
#               Open    High     Low   Close  Volume Currency
# Date
# 2021-09-01  5571.0  5649.5  5559.0  5602.5   18698      ARS
# 2021-09-02  5630.0  5826.0  5630.0  5710.0   18313      ARS
# 2021-09-03  5720.0  5840.0  5720.0  5750.0    9603      ARS
# 2021-09-06  5734.0  5770.0  5620.5  5767.5    9728      ARS
# 2021-09-07  5760.0  5834.0  5657.5  5761.0   18650      ARS

# %%
df_ml.to_csv(r'df_ml_arg.csv', index = False)
